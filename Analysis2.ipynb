# %%
await piplite.install(['skillsnetwork'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 await piplite.install(['skillsnetwork'])
#
# NameError: name 'piplite' is not defined

# %%
pip install (['seaborn'])
# Out:
# zsh:1: no matches found: ([seaborn])
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install (['scikit-learn'])
# Out:
# zsh:1: no matches found: ([scikit-learn])
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install (['scipy'])
# Out:
# zsh:1: no matches found: ([scipy])
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install (['pandas'])
# Out:
# zsh:1: no matches found: ([pandas])
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install (['matplotlib'])
# Out:
# zsh:1: no matches found: ([matplotlib])
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install (['skillsnetwork'])
# Out:
# zsh:1: no matches found: ([skillsnetwork])
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import skillsnetwork
import warnings
warnings.filterwarnings('ignore')

# %%
from pyodide.http import pyfetch

async def download(url, filename):
    response = await pyfetch(url)
    if response.status == 200:
        with open(filename, "wb") as f:
            f.write(await response.bytes())

# %%
pip install wget
# Out:
# Collecting wget
#   Downloading wget-3.2.zip (10 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: wget
#   Building wheel for wget (setup.py) ... done
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9656 sha256=a2265046ba2130769c3b2ee599abd03a83a1b53d40618eda8e66e94fc4451844
#   Stored in directory: /Users/kirti/Library/Caches/pip/wheels/40/b3/0f/a40dbd1c6861731779f62cc4babcb234387e11d697df70ee97
# Successfully built wget
# Installing collected packages: wget
# Successfully installed wget-3.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
URL = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DA0101EN-SkillsNetwork/labs/Data%20files/automobileEDA.csv"
response = requests.get(URL)
open("automobileEDA.csv", "wb").write(response.content)
# Out:
# 35648

# %%
df = pd.read_csv("automobileEDA.csv")
df.head()
# Out:
#    symboling  normalized-losses         make aspiration num-of-doors
# 0          3                122  alfa-romero        std          two  \
# 1          3                122  alfa-romero        std          two
# 2          1                122  alfa-romero        std          two
# 3          2                164         audi        std         four
# 4          2                164         audi        std         four
#
#     body-style drive-wheels engine-location  wheel-base    length  ...
# 0  convertible          rwd           front        88.6  0.811148  ...  \
# 1  convertible          rwd           front        88.6  0.811148  ...
# 2    hatchback          rwd           front        94.5  0.822681  ...
# 3        sedan          fwd           front        99.8  0.848630  ...
# 4        sedan          4wd           front        99.4  0.848630  ...
#
#    compression-ratio  horsepower  peak-rpm city-mpg highway-mpg    price
# 0                9.0       111.0    5000.0       21          27  13495.0  \
# 1                9.0       111.0    5000.0       21          27  16500.0
# 2                9.0       154.0    5000.0       19          26  16500.0
# 3               10.0       102.0    5500.0       24          30  13950.0
# 4                8.0       115.0    5500.0       18          22  17450.0
#
#   city-L/100km  horsepower-binned  diesel  gas
# 0    11.190476             Medium       0    1
# 1    11.190476             Medium       0    1
# 2    12.368421             Medium       0    1
# 3     9.791667             Medium       0    1
# 4    13.055556             Medium       0    1
#
# [5 rows x 29 columns]

# %%
df = pd.read_csv("automobileEDA.csv", header=0)

# %%
df.head()
# Out:
#    symboling  normalized-losses         make aspiration num-of-doors
# 0          3                122  alfa-romero        std          two  \
# 1          3                122  alfa-romero        std          two
# 2          1                122  alfa-romero        std          two
# 3          2                164         audi        std         four
# 4          2                164         audi        std         four
#
#     body-style drive-wheels engine-location  wheel-base    length  ...
# 0  convertible          rwd           front        88.6  0.811148  ...  \
# 1  convertible          rwd           front        88.6  0.811148  ...
# 2    hatchback          rwd           front        94.5  0.822681  ...
# 3        sedan          fwd           front        99.8  0.848630  ...
# 4        sedan          4wd           front        99.4  0.848630  ...
#
#    compression-ratio  horsepower  peak-rpm city-mpg highway-mpg    price
# 0                9.0       111.0    5000.0       21          27  13495.0  \
# 1                9.0       111.0    5000.0       21          27  16500.0
# 2                9.0       154.0    5000.0       19          26  16500.0
# 3               10.0       102.0    5500.0       24          30  13950.0
# 4                8.0       115.0    5500.0       18          22  17450.0
#
#   city-L/100km  horsepower-binned  diesel  gas
# 0    11.190476             Medium       0    1
# 1    11.190476             Medium       0    1
# 2    12.368421             Medium       0    1
# 3     9.791667             Medium       0    1
# 4    13.055556             Medium       0    1
#
# [5 rows x 29 columns]

# %%
pip install -U scikit-learn scipy matplotlib pandas seaborn skillsnetwork
# Out:
# Requirement already satisfied: scikit-learn in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (1.3.0)
# Requirement already satisfied: scipy in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (1.11.2)
# Requirement already satisfied: matplotlib in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (3.7.2)
# Requirement already satisfied: pandas in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (2.0.1)
# Collecting pandas
#   Obtaining dependency information for pandas from https://files.pythonhosted.org/packages/8f/bb/aea1fbeed5b474cb8634364718abe9030d7cc7a30bf51f40bd494bbc89a2/pandas-2.0.3-cp311-cp311-macosx_11_0_arm64.whl.metadata
#   Downloading pandas-2.0.3-cp311-cp311-macosx_11_0_arm64.whl.metadata (18 kB)
# Requirement already satisfied: seaborn in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (0.12.2)
# Requirement already satisfied: skillsnetwork in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (0.20.6)
# Requirement already satisfied: numpy>=1.17.3 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from scikit-learn) (1.24.3)
# Requirement already satisfied: joblib>=1.1.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from scikit-learn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from scikit-learn) (3.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib) (4.42.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib) (23.0)
# Requirement already satisfied: pillow>=6.2.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib) (10.0.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pandas) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pandas) (2023.3)
# Requirement already satisfied: ipython in /Users/kirti/Library/Python/3.11/lib/python/site-packages (from skillsnetwork) (8.14.0)
# Requirement already satisfied: ipywidgets<8,>=7 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from skillsnetwork) (7.8.0)
# Requirement already satisfied: requests<3,>=2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from skillsnetwork) (2.29.0)
# Requirement already satisfied: tqdm<5,>=4 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from skillsnetwork) (4.66.1)
# Requirement already satisfied: comm>=0.1.3 in /Users/kirti/Library/Python/3.11/lib/python/site-packages (from ipywidgets<8,>=7->skillsnetwork) (0.1.4)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from ipywidgets<8,>=7->skillsnetwork) (0.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in /Users/kirti/Library/Python/3.11/lib/python/site-packages (from ipywidgets<8,>=7->skillsnetwork) (5.9.0)
# Requirement already satisfied: widgetsnbextension~=3.6.5 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from ipywidgets<8,>=7->skillsnetwork) (3.6.5)
# Requirement already satisfied: jupyterlab-widgets<3,>=1.0.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from ipywidgets<8,>=7->skillsnetwork) (1.1.5)
# Requirement already satisfied: backcall in /Users/kirti/Library/Python/3.11/lib/python/site-packages (from ipython->skillsnetwork) (0.2.0)
# Requirement already satisfied: decorator in /Users/kirti/Library/Python/3.11/lib/python/site-packages (from ipython->skillsnetwork) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /Users/kirti/Library/Python/3.11/lib/python/site-packages (from ipython->skillsnetwork) (0.19.0)
# Requirement already satisfied: matplotlib-inline in /Users/kirti/Library/Python/3.11/lib/python/site-packages (from ipython->skillsnetwork) (0.1.6)
# Requirement already satisfied: pickleshare in /Users/kirti/Library/Python/3.11/lib/python/site-packages (from ipython->skillsnetwork) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /Users/kirti/Library/Python/3.11/lib/python/site-packages (from ipython->skillsnetwork) (3.0.39)
# Requirement already satisfied: pygments>=2.4.0 in /Users/kirti/Library/Python/3.11/lib/python/site-packages (from ipython->skillsnetwork) (2.16.1)
# Requirement already satisfied: stack-data in /Users/kirti/Library/Python/3.11/lib/python/site-packages (from ipython->skillsnetwork) (0.6.2)
# Requirement already satisfied: pexpect>4.3 in /Users/kirti/Library/Python/3.11/lib/python/site-packages (from ipython->skillsnetwork) (4.8.0)
# Requirement already satisfied: appnope in /Users/kirti/Library/Python/3.11/lib/python/site-packages (from ipython->skillsnetwork) (0.1.3)
# Requirement already satisfied: six>=1.5 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests<3,>=2->skillsnetwork) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests<3,>=2->skillsnetwork) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests<3,>=2->skillsnetwork) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests<3,>=2->skillsnetwork) (2022.12.7)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /Users/kirti/Library/Python/3.11/lib/python/site-packages (from jedi>=0.16->ipython->skillsnetwork) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/kirti/Library/Python/3.11/lib/python/site-packages (from pexpect>4.3->ipython->skillsnetwork) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/kirti/Library/Python/3.11/lib/python/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython->skillsnetwork) (0.2.6)
# Requirement already satisfied: notebook>=4.4.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from widgetsnbextension~=3.6.5->ipywidgets<8,>=7->skillsnetwork) (7.0.2)
# Requirement already satisfied: executing>=1.2.0 in /Users/kirti/Library/Python/3.11/lib/python/site-packages (from stack-data->ipython->skillsnetwork) (1.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/kirti/Library/Python/3.11/lib/python/site-packages (from stack-data->ipython->skillsnetwork) (2.2.1)
# Requirement already satisfied: pure-eval in /Users/kirti/Library/Python/3.11/lib/python/site-packages (from stack-data->ipython->skillsnetwork) (0.2.2)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.5->ipywidgets<8,>=7->skillsnetwork) (2.7.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.22.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.5->ipywidgets<8,>=7->skillsnetwork) (2.24.0)
# Requirement already satisfied: jupyterlab<5,>=4.0.2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.5->ipywidgets<8,>=7->skillsnetwork) (4.0.4)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.5->ipywidgets<8,>=7->skillsnetwork) (0.2.3)
# Requirement already satisfied: tornado>=6.2.0 in /Users/kirti/Library/Python/3.11/lib/python/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.5->ipywidgets<8,>=7->skillsnetwork) (6.3.2)
# Requirement already satisfied: anyio>=3.1.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.5->ipywidgets<8,>=7->skillsnetwork) (3.7.1)
# Requirement already satisfied: argon2-cffi in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.5->ipywidgets<8,>=7->skillsnetwork) (21.3.0)
# Requirement already satisfied: jinja2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.5->ipywidgets<8,>=7->skillsnetwork) (3.1.2)
# Requirement already satisfied: jupyter-client>=7.4.4 in /Users/kirti/Library/Python/3.11/lib/python/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.5->ipywidgets<8,>=7->skillsnetwork) (8.3.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /Users/kirti/Library/Python/3.11/lib/python/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.5->ipywidgets<8,>=7->skillsnetwork) (5.3.1)
# Requirement already satisfied: jupyter-events>=0.6.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.5->ipywidgets<8,>=7->skillsnetwork) (0.7.0)
# Requirement already satisfied: jupyter-server-terminals in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.5->ipywidgets<8,>=7->skillsnetwork) (0.4.4)
# Requirement already satisfied: nbconvert>=6.4.4 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.5->ipywidgets<8,>=7->skillsnetwork) (7.7.3)
# Requirement already satisfied: nbformat>=5.3.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.5->ipywidgets<8,>=7->skillsnetwork) (5.9.2)
# Requirement already satisfied: overrides in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.5->ipywidgets<8,>=7->skillsnetwork) (7.4.0)
# Requirement already satisfied: prometheus-client in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.5->ipywidgets<8,>=7->skillsnetwork) (0.17.1)
# Requirement already satisfied: pyzmq>=24 in /Users/kirti/Library/Python/3.11/lib/python/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.5->ipywidgets<8,>=7->skillsnetwork) (25.1.0)
# Requirement already satisfied: send2trash in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.5->ipywidgets<8,>=7->skillsnetwork) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.5->ipywidgets<8,>=7->skillsnetwork) (0.17.1)
# Requirement already satisfied: websocket-client in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.5->ipywidgets<8,>=7->skillsnetwork) (1.6.1)
# Requirement already satisfied: async-lru>=1.0.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from jupyterlab<5,>=4.0.2->notebook>=4.4.1->widgetsnbextension~=3.6.5->ipywidgets<8,>=7->skillsnetwork) (2.0.4)
# Requirement already satisfied: ipykernel in /Users/kirti/Library/Python/3.11/lib/python/site-packages (from jupyterlab<5,>=4.0.2->notebook>=4.4.1->widgetsnbextension~=3.6.5->ipywidgets<8,>=7->skillsnetwork) (6.25.1)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from jupyterlab<5,>=4.0.2->notebook>=4.4.1->widgetsnbextension~=3.6.5->ipywidgets<8,>=7->skillsnetwork) (2.2.0)
# Requirement already satisfied: babel>=2.10 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.6.5->ipywidgets<8,>=7->skillsnetwork) (2.12.1)
# Requirement already satisfied: json5>=0.9.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.6.5->ipywidgets<8,>=7->skillsnetwork) (0.9.14)
# Requirement already satisfied: jsonschema>=4.17.3 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.6.5->ipywidgets<8,>=7->skillsnetwork) (4.19.0)
# Requirement already satisfied: sniffio>=1.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.5->ipywidgets<8,>=7->skillsnetwork) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from jinja2->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.5->ipywidgets<8,>=7->skillsnetwork) (2.1.2)
# Requirement already satisfied: attrs>=22.2.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from jsonschema>=4.17.3->jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.6.5->ipywidgets<8,>=7->skillsnetwork) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from jsonschema>=4.17.3->jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.6.5->ipywidgets<8,>=7->skillsnetwork) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from jsonschema>=4.17.3->jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.6.5->ipywidgets<8,>=7->skillsnetwork) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from jsonschema>=4.17.3->jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.6.5->ipywidgets<8,>=7->skillsnetwork) (0.9.2)
# Requirement already satisfied: platformdirs>=2.5 in /Users/kirti/Library/Python/3.11/lib/python/site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.5->ipywidgets<8,>=7->skillsnetwork) (3.10.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.5->ipywidgets<8,>=7->skillsnetwork) (2.0.7)
# Requirement already satisfied: pyyaml>=5.3 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.5->ipywidgets<8,>=7->skillsnetwork) (6.0)
# Requirement already satisfied: rfc3339-validator in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.5->ipywidgets<8,>=7->skillsnetwork) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.5->ipywidgets<8,>=7->skillsnetwork) (0.1.1)
# Requirement already satisfied: beautifulsoup4 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.5->ipywidgets<8,>=7->skillsnetwork) (4.12.2)
# Requirement already satisfied: bleach!=5.0.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.5->ipywidgets<8,>=7->skillsnetwork) (6.0.0)
# Requirement already satisfied: defusedxml in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.5->ipywidgets<8,>=7->skillsnetwork) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.5->ipywidgets<8,>=7->skillsnetwork) (0.2.2)
# Requirement already satisfied: mistune<4,>=2.0.3 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.5->ipywidgets<8,>=7->skillsnetwork) (3.0.1)
# Requirement already satisfied: nbclient>=0.5.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.5->ipywidgets<8,>=7->skillsnetwork) (0.8.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.5->ipywidgets<8,>=7->skillsnetwork) (1.5.0)
# Requirement already satisfied: tinycss2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.5->ipywidgets<8,>=7->skillsnetwork) (1.2.1)
# Requirement already satisfied: fastjsonschema in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.5->ipywidgets<8,>=7->skillsnetwork) (2.18.0)
# Requirement already satisfied: argon2-cffi-bindings in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from argon2-cffi->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.5->ipywidgets<8,>=7->skillsnetwork) (21.2.0)
# Requirement already satisfied: debugpy>=1.6.5 in /Users/kirti/Library/Python/3.11/lib/python/site-packages (from ipykernel->jupyterlab<5,>=4.0.2->notebook>=4.4.1->widgetsnbextension~=3.6.5->ipywidgets<8,>=7->skillsnetwork) (1.6.7.post1)
# Requirement already satisfied: nest-asyncio in /Users/kirti/Library/Python/3.11/lib/python/site-packages (from ipykernel->jupyterlab<5,>=4.0.2->notebook>=4.4.1->widgetsnbextension~=3.6.5->ipywidgets<8,>=7->skillsnetwork) (1.5.7)
# Requirement already satisfied: psutil in /Users/kirti/Library/Python/3.11/lib/python/site-packages (from ipykernel->jupyterlab<5,>=4.0.2->notebook>=4.4.1->widgetsnbextension~=3.6.5->ipywidgets<8,>=7->skillsnetwork) (5.9.5)
# Requirement already satisfied: webencodings in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from bleach!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.5->ipywidgets<8,>=7->skillsnetwork) (0.5.1)
# Requirement already satisfied: fqdn in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from jsonschema>=4.17.3->jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.6.5->ipywidgets<8,>=7->skillsnetwork) (1.5.1)
# Requirement already satisfied: isoduration in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from jsonschema>=4.17.3->jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.6.5->ipywidgets<8,>=7->skillsnetwork) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from jsonschema>=4.17.3->jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.6.5->ipywidgets<8,>=7->skillsnetwork) (2.4)
# Requirement already satisfied: uri-template in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from jsonschema>=4.17.3->jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.6.5->ipywidgets<8,>=7->skillsnetwork) (1.3.0)
# Requirement already satisfied: webcolors>=1.11 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from jsonschema>=4.17.3->jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.6.5->ipywidgets<8,>=7->skillsnetwork) (1.13)
# Requirement already satisfied: cffi>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from argon2-cffi-bindings->argon2-cffi->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.5->ipywidgets<8,>=7->skillsnetwork) (1.15.1)
# Requirement already satisfied: soupsieve>1.2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.5->ipywidgets<8,>=7->skillsnetwork) (2.4.1)
# Requirement already satisfied: pycparser in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.5->ipywidgets<8,>=7->skillsnetwork) (2.21)
# Requirement already satisfied: arrow>=0.15.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from isoduration->jsonschema>=4.17.3->jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.6.5->ipywidgets<8,>=7->skillsnetwork) (1.2.3)
# Downloading pandas-2.0.3-cp311-cp311-macosx_11_0_arm64.whl (10.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.7/10.7 MB 6.0 MB/s eta 0:00:0000:0100:01
# Installing collected packages: pandas
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.0.1
#     Uninstalling pandas-2.0.1:
#       Successfully uninstalled pandas-2.0.1
# Successfully installed pandas-2.0.3
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import skillsnetwork
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("automobileEDA.csv", header=0)

# %%
df.head()
# Out:
#    symboling  normalized-losses         make aspiration num-of-doors  \
# 0          3                122  alfa-romero        std          two
# 1          3                122  alfa-romero        std          two
# 2          1                122  alfa-romero        std          two
# 3          2                164         audi        std         four
# 4          2                164         audi        std         four
#
#     body-style drive-wheels engine-location  wheel-base    length  ...  \
# 0  convertible          rwd           front        88.6  0.811148  ...
# 1  convertible          rwd           front        88.6  0.811148  ...
# 2    hatchback          rwd           front        94.5  0.822681  ...
# 3        sedan          fwd           front        99.8  0.848630  ...
# 4        sedan          4wd           front        99.4  0.848630  ...
#
#    compression-ratio  horsepower  peak-rpm city-mpg highway-mpg    price  \
# 0                9.0       111.0    5000.0       21          27  13495.0
# 1                9.0       111.0    5000.0       21          27  16500.0
# 2                9.0       154.0    5000.0       19          26  16500.0
# 3               10.0       102.0    5500.0       24          30  13950.0
# 4                8.0       115.0    5500.0       18          22  17450.0
#
#   city-L/100km  horsepower-binned  diesel  gas
# 0    11.190476             Medium       0    1
# 1    11.190476             Medium       0    1
# 2    12.368421             Medium       0    1
# 3     9.791667             Medium       0    1
# 4    13.055556             Medium       0    1
#
# [5 rows x 29 columns]

# %%
from sklearn.linear_model import LinearRegression

# %%
lm = LinearRegression()
lm
# Out:
# LinearRegression()

# %%
X = df[['highway-mpg']]
Y = df['price']

# %%
lm.fit(X,Y)
# Out:
# LinearRegression()

# %%
Yhat=lm.predict(X)

# %%
Yhat[0:5]
# Out:
# array([16236.50464347, 16236.50464347, 17058.23802179, 13771.3045085 ,
#        20345.17153508])

# %%
lm.intercept_
# Out:
# 38423.305858157415

# %%
lm.coef_
# Out:
# array([-821.73337832])

# %%
lm1 = LinearRegression()
lm1
# Out:
# LinearRegression()

# %%
X = df[['engine-size']]
Y = df['price']

# %%
lm1.fit(X,Y)
lm1
# Out:
# LinearRegression()

# %%
Yhat = lm1.predict(X)

# %%
Yhat[0:5]
# Out:
# array([13728.4631336 , 13728.4631336 , 17399.38347881, 10224.40280408,
#        14729.62322775])

# %%
lm1.intercept_
# Out:
# -7963.338906281046

# %%
lm1.coef_
# Out:
# array([166.86001569])

# %% [markdown]
# -7963.338906281046+166.86001569*engine-size

# %%
Z = df[['horsepower', 'curb-weight', 'engine-size', 'highway-mpg']]

# %% [markdown]
# Z = df[['horsepower', 'curb-weight', 'engine-size', 'highway-mpg']]

# %%
lm.fit(Z, df['price'])
# Out:
# LinearRegression()

# %%
lm.intercept_
# Out:
# -15806.624626329245

# %%
lm.coef_
# Out:
# array([53.49574423,  4.70770099, 81.53026382, 36.05748882])

# %%
Z = df[[ "normalized-losses" , 'highway-mpg']]

# %%
lm2 = LinearRegression()

# %%
lm2
# Out:
# LinearRegression()

# %%
lm2.fit(Z, df['price'])
# Out:
# LinearRegression()

# %%
lm2.intercept_
# Out:
# 38201.31327245733

# %%
lm2.coef_
# Out:
# array([   1.49789586, -820.45434016])

# %%
import seaborn as sns
# %matplotlib inline

# %%
width = 12
height = 10
plt.figure(figsize=(width, height))
sns.regplot(x="highway-mpg", y="price", data=df)
plt.ylim(0,)
# Out:
# (0.0, 48154.999227143104)

# %%
plt.figure(figsize=(width, height))
sns.regplot(x="peak-rpm", y="price", data=df)
plt.ylim(0,)
# Out:
# (0.0, 47414.1)

# %%
df[["peak-rpm","highway-mpg","price"]].corr()
# Out:
#              peak-rpm  highway-mpg     price
# peak-rpm     1.000000    -0.058598 -0.101616
# highway-mpg -0.058598     1.000000 -0.704692
# price       -0.101616    -0.704692  1.000000

# %%
width = 12
height = 10
plt.figure(figsize=(width, height))
sns.residplot(x=df['highway-mpg'],y=df['price'])
plt.show()

# %%
Y_hat = lm2.predict(Z)

# %%
Y_hat
# Out:
# array([16231.78938339, 16231.78938339, 17052.24372355, 13833.33798916,
#        20396.97271047, 17872.69806371, 17926.6223148 , 17872.69806371,
#        22028.89401561, 14695.7334135 , 14695.7334135 , 15510.19617021,
#        15510.19617021, 17872.69806371, 20334.0610842 , 20334.0610842 ,
#        21974.96976453, -5101.52135672,  3068.57044005,  3043.10621038,
#         4739.43703765,  7200.80005814, 13764.43477944,  7245.73693404,
#         7245.73693404,  7245.73693404, 13809.37165535, 13752.45161254,
#        18727.60400874, -5898.00936307,  7229.26007954,  3893.51846781,
#        10457.15318911, 10457.15318911, 10470.63425188, 10422.70158426,
#        11285.09700859, 11285.09700859, 11253.64119546, 11253.64119546,
#        15355.91289628, 12927.50358478, 14590.88070306, 14590.88070306,
#        22829.87570955, 22795.42410469, 24436.33278502, 12923.00989719,
#         7179.82951605,  7179.82951605,  7193.31057882,  7193.31057882,
#        19555.54782822, 19555.54782822, 19555.54782822, 19555.54782822,
#        12140.00295362, 12119.03241153, 12140.00295362, 12119.03241153,
#         3924.97428094, 12119.03241153, 16225.79779993,  6386.33730143,
#        17829.25908368, 17829.25908368, 17829.25908368, 17829.25908368,
#        23615.87844486, 23645.83636212, 25256.78712518, 25256.78712518,
#        18693.15240388,  4803.84655978,  7265.20958027,  7265.20958027,
#        13828.84430157, 13816.86113466, 12175.95245434, 18693.15240388,
#        18693.15240388, 18693.15240388, 12134.01137016, 12134.01137016,
#        13774.92005049, 13792.89480085,  8036.23335694, -2629.67306519,
#         8036.23335694,  8027.24598176,  7998.78596035,  8036.23335694,
#         8036.23335694,  8027.24598176,  7998.78596035,  8096.14919147,
#        10464.64266843, 10464.64266843, 20343.04845938, 20313.09054212,
#        17851.72752163, 17980.54656588, 19621.45524621, 18035.96871283,
#        18751.57034255, 11367.48128108, 18693.15240388, 17872.69806371,
#        18751.57034255, 11367.48128108, 18693.15240388, 17872.69806371,
#        18751.57034255, 11367.48128108, 18751.57034255,  4740.93493351,
#        13765.93267531,  7254.72430922,  7254.72430922,  7254.72430922,
#        13698.52736145, 18693.15240388, 16327.65471865, 17872.69806371,
#        17872.69806371, 17872.69806371, 12949.97202273, 12949.97202273,
#        15453.2761274 , 15384.37291768, 15453.2761274 , 15384.37291768,
#        17094.18480773, 17025.28159801,  8789.28238325, 12891.55408406,
#        12891.55408406,  7997.28806449, 11279.10542514, 12099.5597653 ,
#        17842.74014645, 14560.92278579, 12080.08711908, 12900.54145924,
#        14535.45855612, 19458.18459709,  6333.91094621,  7154.36528637,
#         7134.89264015,  7959.8406679 , 12068.10395217, 12083.08291081,
#         7980.81120999,  7980.81120999,  8801.26555015,  -223.73219164,
#         -223.73219164, 10442.17423048, 10442.17423048, 10557.51221196,
#        10557.51221196, 14659.78391278, 14659.78391278, 13788.40111326,
#        13788.40111326, 13788.40111326, 13788.40111326, 13788.40111326,
#        13788.40111326, 10403.22893803, 11223.68327819, 12044.13761836,
#        12044.13761836, 12044.13761836, 18805.49459363, 18805.49459363,
#        18645.21973625, 18693.15240388,   643.15692029, 10488.60900225,
#          601.21583611, 10446.66791807, 10446.66791807,  3883.03319676,
#        12087.5765984 , 14590.88070306, 14791.59874876, 18693.15240388,
#         7206.79164159, 12949.97202273, 15382.87502182, 15339.43604178,
#        15382.87502182, 15339.43604178, 20305.6010628 , 20262.16208276,
#        15370.89185491, 17832.2548754 , 19473.16355573, 16191.34619508,
#        17832.2548754 ])

# %%
plt.figure(figsize=(width, height))
ax1 = sns.distplot(df['price'], hist=False, color="r", label="Actual Value")
sns.distplot(Y_hat, hist=False, color="b", label="Fitted Values" , ax=ax1)

plt.title('Actual vs Fitted Values for Price')
plt.xlabel('Price (in dollars)')
plt.ylabel('Proportion of Cars')

plt.show()
plt.close()

# %%
def PlotPolly(model, independent_variable, dependent_variabble, Name):
    x_new = np.linspace(15, 55, 100)
    y_new = model(x_new)

    plt.plot(independent_variable, dependent_variabble, '.', x_new, y_new, '-')
    plt.title('Polynomial Fit with Matplotlib for Price ~ Length')
    ax = plt.gca()
    ax.set_facecolor((0.898, 0.898, 0.898))
    fig = plt.gcf()
    plt.xlabel(Name)
    plt.ylabel('Price of Cars')

    plt.show()
    plt.close()

# %%
x = df['highway-mpg']
y = df['price']

# %%
f = np.polyfit(x, y, 3)
p = np.poly1d(f)
print(p)
# Out:
#         3         2
# -1.557 x + 204.8 x - 8965 x + 1.379e+05

# %%
PlotPolly(p, x, y, 'highway-mpg')

# %%
np.polyfit(x, y, 3)
# Out:
# array([-1.55663829e+00,  2.04754306e+02, -8.96543312e+03,  1.37923594e+05])

# %%
f1 = np.polyfit(x, y, 11)
p1 = np.poly1d(f1)
print(p1)
PlotPolly(p1,x,y, 'Highway MPG')
# Out:
#             11             10             9           8         7
# -1.243e-08 x  + 4.722e-06 x  - 0.0008028 x + 0.08056 x - 5.297 x
#           6        5             4             3             2
#  + 239.5 x - 7588 x + 1.684e+05 x - 2.565e+06 x + 2.551e+07 x - 1.491e+08 x + 3.879e+08

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
pr=PolynomialFeatures(degree=2)
pr
# Out:
# PolynomialFeatures()

# %%
Z_pr=pr.fit_transform(Z)

# %%
Z.shape
# Out:
# (201, 2)

# %%
Z_pr.shape
# Out:
# (201, 6)

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

# %%
Input=[('scale',StandardScaler()), ('polynomial', PolynomialFeatures(include_bias=False)), ('model',LinearRegression())]

# %%
pipe=Pipeline(Input)
pipe
# Out:
# Pipeline(steps=[('scale', StandardScaler()),
#                 ('polynomial', PolynomialFeatures(include_bias=False)),
#                 ('model', LinearRegression())])

# %%
Z = Z.astype(float)
pipe.fit(Z,y)
# Out:
# Pipeline(steps=[('scale', StandardScaler()),
#                 ('polynomial', PolynomialFeatures(include_bias=False)),
#                 ('model', LinearRegression())])

# %%
ypipe=pipe.predict(Z)
ypipe[0:4]
# Out:
# array([15388.77780567, 15388.77780567, 16771.84474515, 11641.85647791])

# %%
Input=[('scale',StandardScaler()),('model',LinearRegression())]

pipe=Pipeline(Input)

pipe.fit(Z,y)

ypipe=pipe.predict(Z)
ypipe[0:10]
# Out:
# array([16231.78938339, 16231.78938339, 17052.24372355, 13833.33798916,
#        20396.97271047, 17872.69806371, 17926.6223148 , 17872.69806371,
#        22028.89401561, 14695.7334135 ])

# %%
lm
# Out:
# LinearRegression()

# %%
lm2
# Out:
# LinearRegression()

# %%
X = df[['highway-mpg']]
Y = df['price']

# %%
lm.fit(X, Y)
# Find the R^2
print('The R-square is: ', lm.score(X, Y))
# Out:
# The R-square is:  0.4965911884339175

# %%
Yhat=lm.predict(X)
print('The output of the first four predicted value is: ', Yhat[0:4])
# Out:
# The output of the first four predicted value is:  [16236.50464347 16236.50464347 17058.23802179 13771.3045085 ]

# %%
from sklearn.metrics import mean_squared_error

# %%
mse = mean_squared_error(df['price'], Yhat)
print('The mean square error of price and predicted value is: ', mse)
# Out:
# The mean square error of price and predicted value is:  31635042.944639895

# %%
Z = df[['horsepower', 'curb-weight', 'engine-size', 'highway-mpg']]

# %%
lm.fit(Z, df['price'])
# Find the R^2
print('The R-square is: ', lm.score(Z, df['price']))
# Out:
# The R-square is:  0.8093562806577458

# %%
Y_predict_multifit = lm.predict(Z)

# %%
print('The mean square error of price and predicted value using multifit is: ', \
      mean_squared_error(df['price'], Y_predict_multifit))
# Out:
# The mean square error of price and predicted value using multifit is:  11980366.870726489

# %%
from sklearn.metrics import r2_score

# %%
r_squared = r2_score(y, p(x))
print('The R-square value is: ', r_squared)
# Out:
# The R-square value is:  0.674194666390652

# %%
mean_squared_error(df['price'], p(x))
# Out:
# 20474146.426361218

# %%
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

# %%
new_input=np.arange(1, 100, 1).reshape(-1, 1)

# %%
lm.fit(X, Y)
lm
# Out:
# LinearRegression()

# %%
yhat=lm.predict(new_input)
yhat[0:5]
# Out:
# array([37601.57247984, 36779.83910151, 35958.10572319, 35136.37234487,
#        34314.63896655])

# %%
plt.plot(new_input, yhat)
plt.show()
